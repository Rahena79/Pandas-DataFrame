# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahena79/Pandas-DataFrame/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c12e5385-7cf7-4e59-b8ab-9978731f277e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c12e5385-7cf7-4e59-b8ab-9978731f277e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pd.read_csv('student.csv')
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df = pd.read_csv('student.csv')
print(df)
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-0e566b70f572> in <cell line: 0>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.describe()
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26            NaN
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
df[['name','mark']]
# Out:
#            name  mark
# 0      John Deo    75
# 1      Max Ruin    85
# 2        Arnold    55
# 3    Krish Star    60
# 4     John Mike    60
# 5     Alex John    55
# 6   My John Rob    78
# 7        Asruid    85
# 8       Tes Qry    78
# 9      Big John    55
# 10       Ronald    89
# 11        Recky    94
# 12          Kty    88
# 13         Bigy    88
# 14     Tade Row    88
# 15        Gimmy    88
# 16        Tumyu    54
# 17        Honny    75
# 18        Tinny    18
# 19       Jackly    65
# 20   Babby John    69
# 21       Reggid    55
# 22        Herod    79
# 23    Tiddy Now    78
# 24     Giff Tow    88
# 25       Crelea    79
# 26          NaN    81
# 27    Rojj Base    86
# 28  Tess Played    55
# 29    Reppy Red    79
# 30  Marry Toeey    88
# 31    Binn Rott    90
# 32    Kenn Rein    96
# 33     Gain Toe    69
# 34   Rows Noump    88

# %%
df.head(3)
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %%
df['class']
# Out:
# 35

# %%
df.loc[:, "class", "four"]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-91-0990c3b7baf0> in <cell line: 0>()
# ----> 1 df.loc[:, "class", "four"]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1369
#    1370         # no multi-index, so validate all of the indexers
# -> 1371         tup = self._validate_tuple_indexer(tup)
#    1372
#    1373         # ugly hack for GH #836
#
# ...

# %%
df[df["class"] == "four"]
# Out:
#     id         name class  mark  gender
# 0    1     John Deo  four    75  female
# 1    2     Max Ruin  four    85    male
# 2    3       Arnold  four    55    male
# 3    4   Krish Star  four    60  female
# 4    5    John Mike  four    60  female
# 5    6    Alex John  four    55    male
# 6    7  My John Rob  four    78    male
# 7    8       Asruid  four    85    male
# 8    9      Tes Qry  four    78     NaN
# 9   10     Big John  four    55  female
# 10  11       Ronald  four    89  female
# 11  12        Recky  four    94  female
# 12  13          Kty  four    88  female
# 13  14         Bigy  four    88  female
# 14  15     Tade Row  four    88    male
# 15  16        Gimmy  four    88    male
# 16  17        Tumyu  four    54    male
# 17  18        Honny  four    75    male
# 18  19        Tinny  four    18    male
# 19  20       Jackly  four    65  female
# 20  21   Babby John  four    69  female
# 21  22       Reggid  four    55  female
# ...

# %%
df["passed"] = df["mark"] >= 60
df
# Out:
#     id         name class  mark  gender  passed
# 0    1     John Deo  four    75  female    True
# 1    2     Max Ruin  four    85    male    True
# 2    3       Arnold  four    55    male   False
# 3    4   Krish Star  four    60  female    True
# 4    5    John Mike  four    60  female    True
# 5    6    Alex John  four    55    male   False
# 6    7  My John Rob  four    78    male    True
# 7    8       Asruid  four    85    male    True
# 8    9      Tes Qry  four    78     NaN    True
# 9   10     Big John  four    55  female   False
# 10  11       Ronald  four    89  female    True
# 11  12        Recky  four    94  female    True
# 12  13          Kty  four    88  female    True
# 13  14         Bigy  four    88  female    True
# 14  15     Tade Row  four    88    male    True
# 15  16        Gimmy  four    88    male    True
# 16  17        Tumyu  four    54    male   False
# 17  18        Honny  four    75    male    True
# 18  19        Tinny  four    18    male   False
# ...

# %%
df.rename(columns={"mark": "score"}, inplace=True)
df
# Out:
#     id         name class  score  gender  passed
# 0    1     John Deo  four     75  female    True
# 1    2     Max Ruin  four     85    male    True
# 2    3       Arnold  four     55    male   False
# 3    4   Krish Star  four     60  female    True
# 4    5    John Mike  four     60  female    True
# 5    6    Alex John  four     55    male   False
# 6    7  My John Rob  four     78    male    True
# 7    8       Asruid  four     85    male    True
# 8    9      Tes Qry  four     78     NaN    True
# 9   10     Big John  four     55  female   False
# 10  11       Ronald  four     89  female    True
# 11  12        Recky  four     94  female    True
# 12  13          Kty  four     88  female    True
# 13  14         Bigy  four     88  female    True
# 14  15     Tade Row  four     88    male    True
# 15  16        Gimmy  four     88    male    True
# 16  17        Tumyu  four     54    male   False
# 17  18        Honny  four     75    male    True
# ...

# %%
df.drop(columns=["passed"], inplace=True)
df
# Out:
#     id         name class  score  gender
# 0    1     John Deo  four     75  female
# 1    2     Max Ruin  four     85    male
# 2    3       Arnold  four     55    male
# 3    4   Krish Star  four     60  female
# 4    5    John Mike  four     60  female
# 5    6    Alex John  four     55    male
# 6    7  My John Rob  four     78    male
# 7    8       Asruid  four     85    male
# 8    9      Tes Qry  four     78     NaN
# 9   10     Big John  four     55  female
# 10  11       Ronald  four     89  female
# 11  12        Recky  four     94  female
# 12  13          Kty  four     88  female
# 13  14         Bigy  four     88  female
# 14  15     Tade Row  four     88    male
# 15  16        Gimmy  four     88    male
# 16  17        Tumyu  four     54    male
# 17  18        Honny  four     75    male
# 18  19        Tinny  four     18    male
# 19  20       Jackly  four     65  female
# 20  21   Babby John  four     69  female
# 21  22       Reggid  four     55  female
# ...
